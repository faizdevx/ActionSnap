# %%
import torch
import flask

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Flask ready")

# %%
from transformer import ActionClassificationTransformer

model = ActionClassificationTransformer.load_from_checkpoint("models/saved_model.ckpt")
model.eval()
print("Transformer checkpoint loaded successfully")
print(model.hparams)

# %%
import subprocess
import sys
import time
import urllib.request

PORT = 5000
server = subprocess.Popen([sys.executable, "webcam_app.py"])
time.sleep(5)
status = urllib.request.urlopen(f"http://127.0.0.1:{PORT}/").status
print("Server status:", status)
print(f"Open: http://127.0.0.1:{PORT}/")

# %%
server.terminate()
server.wait(timeout=10)
print("Server stopped")
